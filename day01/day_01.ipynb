# %% [markdown]
# # **Day 01: Installation and Hello World🌍🐍**

# %% [markdown]
# How to Install Python and Set Up Your IDE?

# %% [markdown]
# ✅ Step 1: Install Python
#
# Go to https://python.org
#
# Click "Download Python" (it picks the right version for your OS).
#
# Run the installer.
#
# ⚠️ Check the box that says “Add Python to PATH” before clicking Install.

# %% [markdown]
# ✅ Step 2: Install Visual Studio Code (VSCode)
# Go to https://code.visualstudio.com
#
# Download and install VSCode.

# %% [markdown]
# ✅ Step 3: Install Python Extension in VSCode
#
# Open VSCode → Go to Extensions (left sidebar) → Search "Python" → Install the one from Microsoft.

# %% [markdown]
# Or Watch this video for better understanding: https://www.youtube.com/watch?v=mIVB-SNycKI

# %% [markdown]
# Before writing our first code let's understand few things......

# %% [markdown]
# In the community, this question has been asked: "What is an IDE? Can't we write and run a program directly in Python itself?"🤔
#
# Here are a few screenshots from the community discussion.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The Answer is👇

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 🐍 Can't We Write Python Without an IDE?
#
# Yes, you can!
#
# Python comes with something called:
#
# ▶️ IDLE (Python’s built-in editor)
# After installing Python:
#
# You can open IDLE, a simple window that lets you:
#
# Write Python code
#
# Run it directly
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Why Use an IDE like VSCode?

# %% [markdown]
# IDLE is great for quick tests and learning the very basics.
# But it lacks many features you’ll need as you grow like extensions, smart suggestions, and project management.
# It’s not ideal for larger projects or serious coding.
# That’s why most developers (even beginners) switch to tools like VSCode early on.

# %% [markdown]
# ✅ What is Syntax in Python?
#
# Let's understand what is Syntax in Python.....
#
# Syntax refers to the set of rules that defines how a Python program is written and interpreted.
# Think of it like grammar in a spoken language just as English has rules (like subject-verb agreement),
# Python has rules for how code must be written so the computer can understand and run it.
#
# Simple Analogy:
# English sentence: I am eating.
#
# Python statement: print("Hello, world!")
#
# Both must follow correct structure (syntax) to make sense.
#
# 🐍 Examples of Python Syntax:
# 1. Printing something = print("Hello, world!")
#
# 2. Variables: x = 10
#               name = "Alice"
#
# 3. Indentation
# Python uses indentation (spaces/tabs) to define blocks of code.
# Ex: if x > 5:
#     print("x is greater than 5")
#
# 4. Comments
# Comment is a line of text that the Python interpreter ignores when running the code. Comments are used to explain the code, make notes, or temporarily disable parts of the code during debugging.
# Ex: # This is a single-line comment
#
#      """
#      This is a
#       multi-line comment
#      """
#
# 5. Input from User:
# name = input("Enter your name: ")
# print("Hello, " + name)
#
# These are the few example of python syntax you can also explore
# Functions, Loops, Conditionals, Lists, Dictionaries.

# %% [markdown]
# 🎯 Challenge
# - Write a program that prints "Hello, World!" followed by your name

# %%
print("Hello World")
print("My name is Sahib")
# Out:
# Hello World
# My name is Sahib
